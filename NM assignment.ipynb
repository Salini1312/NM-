# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv('F:/Dataset/House Price India.csv')
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %% [markdown]
# # Univariate Analysis

# %%
df.dtypes
# Out:
# id                                         int64
# Date                                       int64
# number of bedrooms                         int64
# number of bathrooms                      float64
# living area                                int64
# lot area                                   int64
# number of floors                         float64
# waterfront present                         int64
# number of views                            int64
# condition of the house                     int64
# grade of the house                         int64
# Area of the house(excluding basement)      int64
# Area of the basement                       int64
# Built Year                                 int64
# Renovation Year                            int64
# Postal Code                                int64
# Lattitude                                float64
# Longitude                                float64
# living_area_renov                          int64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.scatter(df.id,df['living area'])
plt.show()

# %%
sns.scatterplot(x=df.id, y=df['living area'], hue=df['lot area'])
# Out:
# <Axes: xlabel='id', ylabel='living area'>

# %%
sns.set(rc={'figure.figsize':(7,7)})
sns.set(font_scale=1.5)

# %%
fig=sns.lineplot(x=df.id,y=df['living area'], markevery=1, marker='d',data=df['lot area'])
fig.set(xlabel='id')
# Out:
# [Text(0.5, 0, 'id')]

# %%
sns.stripplot(y=df['living area'])
# Out:
# <Axes: ylabel='living area'>

# %%
sns.histplot(df['id'])
# Out:
# <Axes: xlabel='id', ylabel='Count'>

# %%
sns.displot(df['living area'],kde=False,color='black',bins=10)

# %%
plt.figure(figsize=(5,5))
df['living area'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.set(rc={'figure.figsize':(5,5)})
sns.kdeplot(df['living area'], fill=True)
# Out:
# <Axes: xlabel='living area', ylabel='Density'>

# %%
fig, ax=plt.subplots()
sns.rugplot(df['id'])
ax.set_xlim(10,20)
plt.show()

# %%
sns.distplot(df['living area'], rug=True, hist=False)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14500\2325145322.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['living area'], rug=True, hist=False)
# <Axes: xlabel='living area', ylabel='Density'>

# %%
plt.boxplot(df['living area'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21b9b0ae980>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x21b9b0aeec0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x21b9b0ae6e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x21b9b0af400>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21b9b0af6a0>],
#  'means': []}

# %%
sns.set(rc={'figure.figsize':(6,6)})
sns.displot(df['living area'],color='black',rug=True)

# %%
dfM=df.drop('id',axis=1)

# %%
plt.figure(figsize=(7,7))
plt.violinplot(dfM.values,showmedians=True)
plt.show()

# %%
sns.set(rc={'figure.figsize':(5,5)})
sns.violinplot(df['living area'], orient='vertical')
# Out:
# <Axes: >

# %%
sns.countplot(df[])
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Bivariate Analysis

# %%
import pandas as pd

# %%
df=pd.read_csv('F:/Dataset/House Price India.csv')
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15, 5))
sns.barplot(x=df['id'], y=df['living area'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df[df['id'] < 100].plot.scatter(x='id', y='lot area')
# Out:
# <Axes: xlabel='id', ylabel='lot area'>

# %%
sns.scatterplot(x=df['id'],y=df['living area'])

# %% [markdown]
# # Multivariate Analysis

# %%
from sklearn import datasets, decomposition
iris = datasets.load_iris()
X = iris.data
y = iris.target
pca = decomposition.PCA(n_components=2)
X = pca.fit_transform(X)
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y)
# Out:
# <Axes: >

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from scipy import stats

# %%
pd.plotting.scatter_matrix(df.loc[:, "id":"living area"], diagonal="kde",figsize=(20,15))
plt.show()

# %%
ax = df[["living area","number of floors","number of bathrooms","number of bedrooms"]].plot(figsize=(15,10))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5));

# %%
ax = df[["lot area","living area"]].plot(figsize=(15,10))
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5));

# %%
sns.heatmap(df.corr(),annot=True)
sns. set(font_scale=0.5)

# %% [markdown]
# # Descriptive Statistics

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("House Price India.csv")
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
df.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# ...

# %%
df.mean(axis=1)
# Out:
# 0        2.941470e+08
# 1        2.941041e+08
# 2        2.940958e+08
# 3        2.940832e+08
# 4        2.940783e+08
#              ...
# 14615    2.940548e+08
# 14616    2.940537e+08
# 14617    2.940531e+08
# 14618    2.940530e+08
# 14619    2.940503e+08
# Length: 14620, dtype: float64

# %%
df.median()
# Out:
# id                                       6.762821e+09
# Date                                     4.260000e+04
# number of bedrooms                       3.000000e+00
# number of bathrooms                      2.250000e+00
# living area                              1.930000e+03
# lot area                                 7.620000e+03
# number of floors                         1.500000e+00
# waterfront present                       0.000000e+00
# number of views                          0.000000e+00
# condition of the house                   3.000000e+00
# grade of the house                       7.000000e+00
# Area of the house(excluding basement)    1.580000e+03
# Area of the basement                     0.000000e+00
# Built Year                               1.975000e+03
# Renovation Year                          0.000000e+00
# Postal Code                              1.220320e+05
# Lattitude                                5.280640e+01
# ...

# %%
norm_data = pd.DataFrame(np.random.normal(size=100000))

norm_data.plot(kind="density",
              figsize=(10,10));


plt.vlines(norm_data.mean(),     # Plot black line at mean
           ymin=0, 
           ymax=0.4,
           linewidth=5.0);

plt.vlines(norm_data.median(),   # Plot red line at median
           ymin=0, 
           ymax=0.4, 
           linewidth=2.0,
           color="red");

# %%
skewed_data = pd.DataFrame(np.random.exponential(size=100000))

skewed_data.plot(kind="density",
              figsize=(10,10),
              xlim=(-1,5));


plt.vlines(skewed_data.mean(),     # Plot black line at mean
           ymin=0, 
           ymax=0.8,
           linewidth=5.0);

plt.vlines(skewed_data.median(),   # Plot red line at median
           ymin=0, 
           ymax=0.8, 
           linewidth=2.0,
           color="red");

# %%
norm_data = np.random.normal(size=50)
outliers = np.random.normal(15, size=3)
combined_data = pd.DataFrame(np.concatenate((norm_data, outliers), axis=0))

combined_data.plot(kind="density",
              figsize=(10,10),
              xlim=(-5,20));


plt.vlines(combined_data.mean(),     # Plot black line at mean
           ymin=0, 
           ymax=0.2,
           linewidth=5.0);

plt.vlines(combined_data.median(),   # Plot red line at median
           ymin=0, 
           ymax=0.2, 
           linewidth=2.0,
           color="red");

# %%
df.mode()
# Out:
#                id     Date  number of bedrooms  number of bathrooms  \
# 0      6762810020  42543.0                 3.0                  2.5
# 1      6762810021      NaN                 NaN                  NaN
# 2      6762810022      NaN                 NaN                  NaN
# 3      6762810023      NaN                 NaN                  NaN
# 4      6762810026      NaN                 NaN                  NaN
# ...           ...      ...                 ...                  ...
# 14615  6762831611      NaN                 NaN                  NaN
# 14616  6762831612      NaN                 NaN                  NaN
# 14617  6762831613      NaN                 NaN                  NaN
# 14618  6762831615      NaN                 NaN                  NaN
# 14619  6762831616      NaN                 NaN                  NaN
#
#        living area  lot area  number of floors  waterfront present  \
# 0           1400.0    5000.0               1.0                 0.0
# ...

# %%
max(df["living area"]) - min(df["lot area"])
# Out:
# 13020

# %%
five_num = [df["lot area"].quantile(0),   
            df["lot area"].quantile(0.25),
            df["lot area"].quantile(0.50),
            df["lot area"].quantile(0.75),
            df["lot area"].quantile(1)]

five_num
# Out:
# [520.0, 5010.75, 7620.0, 10800.0, 1074218.0]

# %%
df["living area"].describe()
# Out:
# count    14620.000000
# mean      2098.262996
# std        928.275721
# min        370.000000
# 25%       1440.000000
# 50%       1930.000000
# 75%       2570.000000
# max      13540.000000
# Name: living area, dtype: float64

# %%
df["living area"].quantile(0.75) - df["living area"].quantile(0.25)
# Out:
# 1130.0

# %%
df.boxplot(column="living area",
               return_type='axes',
               figsize=(8,8))

plt.text(x=0.74, y=22.25, s="3rd Quartile")
plt.text(x=0.8, y=18.75, s="Median")
plt.text(x=0.75, y=15.5, s="1st Quartile")
plt.text(x=0.9, y=10, s="Min")
plt.text(x=0.9, y=33.5, s="Max")
plt.text(x=0.7, y=19.5, s="IQR", rotation=90, size=25);

# %%
df["living area"].var()
# Out:
# 861695.8146098064

# %%
df["living area"].std()
# Out:
# 928.2757212217749

# %%
abs_median_devs = abs(df["living area"] - df["living area"].median())

abs_median_devs.median() * 1.4826
# Out:
# 815.43

# %%
df["living area"].skew()
# Out:
# 1.538336624376669

# %%
df["living area"].kurt()
# Out:
# 6.0736171462473205

# %%
norm_data = np.random.normal(size=100000)
skewed_data = np.concatenate((np.random.normal(size=35000)+2, 
                             np.random.exponential(size=65000)), 
                             axis=0)
uniform_data = np.random.uniform(0,2, size=100000)
peaked_data = np.concatenate((np.random.exponential(size=50000),
                             np.random.exponential(size=50000)*(-1)),
                             axis=0)

data_df = pd.DataFrame({"norm":norm_data,
                       "skewed":skewed_data,
                       "uniform":uniform_data,
                       "peaked":peaked_data})

# %%
data_df.plot(kind="density",
            figsize=(10,10),
            xlim=(-5,5));

# %%
data_df.skew()
# Out:
# norm      -0.005796
# skewed     1.012751
# uniform   -0.005778
# peaked     0.003422
# dtype: float64

# %%
data_df.kurt()
# Out:
# norm       0.023613
# skewed     1.384883
# uniform   -1.196186
# peaked     3.030710
# dtype: float64

# %% [markdown]
# # Handle the missing values

# %%
import os
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn import preprocessing
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.linear_model import LogisticRegression

import missingno as msno

# %%
df= pd.read_csv("House Price India.csv")

# %%
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
print(df.head())
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df = df.dropna()

# %%
print("\nDataset after dropping missing values:")
print(df.head())
# Out:
# Dataset after dropping missing values:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
# ...
